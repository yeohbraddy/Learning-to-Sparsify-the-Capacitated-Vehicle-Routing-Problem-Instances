# %%
import numpy as np
import matplotlib.pyplot as plt
import re
from linecache import getline
from gurobipy import Model, GRB, quicksum

# %%
def parseNumVehicles(line):
    x = re.findall(r"No of trucks: [0-9]", line)
    return int(x[0][-1])

def parseForNum(line):
    x = re.findall(r"[0-9]+", line)
    return int(x[0])

def parseCoords(line):
    x = line.split()
    return [int(x[1]), int(x[2])]

def parseDemand(line):
    x = line.split()
    return [int(x[0]), int(x[1])]

# %%
COORD_FLAG = False
DEMAND_FLAG = False
xc = []
yc = []
q = {}
     
fh = open("../Instances/Instances/E-n33-k4.txt", 'r')
for i,line in enumerate(fh):
    if "CAPACITY" in line:
        Q = parseForNum(line)
    elif "COMMENT" in line:
        p = parseNumVehicles(line)
    elif "DIMENSION" in line:
        n = int(parseForNum(line)) - 1 # number of clients
    elif "NODE_COORD_SECTION" in line:
        COORD_FLAG = True
    elif "DEMAND_SECTION" in line:
        COORD_FLAG = False
        DEMAND_FLAG = True
    elif "DEPOT_SECTION" in line:
        DEMAND_FLAG = False
        print()
    elif COORD_FLAG:
        coord = parseCoords(line)
        xc.append(coord[0])
        yc.append(coord[1])
    elif DEMAND_FLAG:
        demand = parseDemand(line)
        q[demand[0]] = demand[1]
fh.close()

# %%
plt.rcParams["figure.figsize"] = [16,9]
plt.plot(xc[0], yc[0], c='r', marker='s')
plt.scatter(xc[1:], yc[1:], c='black')

# %%
# Number of clients
N = [i for i in range(1, n+1)] 

# Number of nodes (including depot)
V = [0] + N 

# Arcs
A = [(i, j) for i in V for j in V] 

# Cost
c = {(i, j): np.hypot(xc[i] - xc[j], yc[i] - yc[j]) for i, j in A}

# %%
mdl = Model('CVRP')
# Out:
# Academic license - for non-commercial use only - expires 2021-03-18
# Using license file C:\Users\BigBadBraddy\gurobi.lic

# %% [markdown]
# ## Variables
#
# ![image.png](attachment:image.png)

# %%
x = mdl.addVars(A, vtype=GRB.CONTINUOUS)
u = mdl.addVars(N, vtype=GRB.CONTINUOUS)
mdl.update()

# %% [markdown]
# ## Objective Function
#
# ![image.png](attachment:image.png)

# %%
mdl.modelSense = GRB.MINIMIZE
mdl.setObjective(quicksum(c[i, j] * x[i, j] for i, j in A))
mdl.update()

# %% [markdown]
# ## Constraint 1
#
# ![image.png](attachment:image.png)

# %%
mdl.addConstrs(quicksum(x[i, j] for i in V if i != j) == 1 for j in N)
mdl.update()

# %% [markdown]
# ## Constraint 2
#
# ![image.png](attachment:image.png)

# %%
mdl.addConstrs(quicksum(x[i, j] for j in V if j != i) == 1 for i in N)
mdl.update()

# %% [markdown]
# ## Constraint 3
#
# ![image.png](attachment:image.png)

# %%
mdl.addConstr(quicksum(x[i, 0] for i in V) == p)
mdl.update()

# %% [markdown]
# ## Constraint 4
#
# ![image.png](attachment:image.png)

# %%
mdl.addConstr(quicksum(x[0, j] for j in V) == p)
mdl.update()

# %% [markdown]
# ## Constraint 5
#
# ![image.png](attachment:image.png)

# %%
mdl.addConstrs((u[j] - u[i]) >= (q[j] - Q*(1 - x[i, j])) for i in N for j in N if i != j)
mdl.update()

# %% [markdown]
# ## Constraint 6
#
# ![image.png](attachment:image.png)

# %%
mdl.addConstrs(u[i] >= q[i] for i in N)
mdl.addConstrs(u[i] <= Q for i in N)
mdl.update()

# %%
# mdl.Params.MIPGap = 0.1
# mdl.Params.TimeLimit = 540  # seconds
# mdl.setParam("MIPFocus", 3);
# mdl.setParam("Cut", -1);
# mdl.setParam("Heuristics", 1);
mdl.optimize()

#760s
#40s
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1122 rows, 1121 columns and 5154 nonzeros
# Model fingerprint: 0x46716a68
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+03]
# Presolve removed 65 rows and 33 columns
# Presolve time: 0.03s
# Presolved: 1057 rows, 1088 columns, 5056 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.400000e+01   0.000000e+00      0s
#      122    3.0395435e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 122 iterations and 0.04 seconds
# Optimal objective  3.039543453e+02

# %%
print(x)
# Out:
# {(0, 0): <gurobi.Var C0 (value 4.0)>, (0, 1): <gurobi.Var C1 (value 0.0)>, (0, 2): <gurobi.Var C2 (value 0.0)>, (0, 3): <gurobi.Var C3 (value 0.0)>, (0, 4): <gurobi.Var C4 (value 0.0)>, (0, 5): <gurobi.Var C5 (value 0.0)>, (0, 6): <gurobi.Var C6 (value 0.0)>, (0, 7): <gurobi.Var C7 (value 0.0)>, (0, 8): <gurobi.Var C8 (value 0.0)>, (0, 9): <gurobi.Var C9 (value 0.0)>, (0, 10): <gurobi.Var C10 (value 0.0)>, (0, 11): <gurobi.Var C11 (value 0.0)>, (0, 12): <gurobi.Var C12 (value 0.0)>, (0, 13): <gurobi.Var C13 (value 0.0)>, (0, 14): <gurobi.Var C14 (value 0.0)>, (0, 15): <gurobi.Var C15 (value 0.0)>, (0, 16): <gurobi.Var C16 (value 0.0)>, (0, 17): <gurobi.Var C17 (value 0.0)>, (0, 18): <gurobi.Var C18 (value 0.0)>, (0, 19): <gurobi.Var C19 (value 0.0)>, (0, 20): <gurobi.Var C20 (value 0.0)>, (0, 21): <gurobi.Var C21 (value 0.0)>, (0, 22): <gurobi.Var C22 (value 0.0)>, (0, 23): <gurobi.Var C23 (value 0.0)>, (0, 24): <gurobi.Var C24 (value 0.0)>, (0, 25): <gurobi.Var C25 (value 0.0)>, (0, 26): <gurobi.Var C26 (value 0.0)>, (0, 27): <gurobi.Var C27 (value 0.0)>, (0, 28): <gurobi.Var C28 (value 0.0)>, (0, 29): <gurobi.Var C29 (value 0.0)>, (0, 30): <gurobi.Var C30 (value 0.0)>, (0, 31): <gurobi.Var C31 (value 0.0)>, (0, 32): <gurobi.Var C32 (value 0.0)>, (1, 0): <gurobi.Var C33 (value 0.0)>, (1, 1): <gurobi.Var C34 (value 0.0)>, (1, 2): <gurobi.Var C35 (value 0.0)>, (1, 3): <gurobi.Var C36 (value 0.0)>, (1, 4): <gurobi.Var C37 (value 0.0)>, (1, 5): <gurobi.Var C38 (value 0.0)>, (1, 6): <gurobi.Var C39 (value 0.0)>, (1, 7): <gurobi.Var C40 (value 0.0)>, (1, 8): <gurobi.Var C41 (value 0.0)>, (1, 9): <gurobi.Var C42 (value 0.0)>, (1, 10): <gurobi.Var C43 (value 0.0)>, (1, 11): <gurobi.Var C44 (value 0.0)>, (1, 12): <gurobi.Var C45 (value 0.0)>, (1, 13): <gurobi.Var C46 (value 1.0)>, (1, 14): <gurobi.Var C47 (value 0.0)>, (1, 15): <gurobi.Var C48 (value 0.0)>, (1, 16): <gurobi.Var C49 (value 0.0)>, (1, 17): <gurobi.Var C50 (value 0.0)>, (1, 18): <gurobi.Var C51 (value 0.0)>, (1, 19): <gurobi.Var C52 (value 0.0)>, (1, 20): <gurobi.Var C53 (value 0.0)>, (1, 21): <gurobi.Var C54 (value 0.0)>, (1, 22): <gurobi.Var C55 (value 0.0)>, (1, 23): <gurobi.Var C56 (value 0.0)>, (1, 24): <gurobi.Var C57 (value 0.0)>, (1, 25): <gurobi.Var C58 (value 0.0)>, (1, 26): <gurobi.Var C59 (value 0.0)>, (1, 27): <gurobi.Var C60 (value 0.0)>, (1, 28): <gurobi.Var C61 (value 0.0)>, (1, 29): <gurobi.Var C62 (value 0.0)>, (1, 30): <gurobi.Var C63 (value 0.0)>, (1, 31): <gurobi.Var C64 (value 0.0)>, (1, 32): <gurobi.Var C65 (value 0.0)>, (2, 0): <gurobi.Var C66 (value 0.0)>, (2, 1): <gurobi.Var C67 (value 0.0)>, (2, 2): <gurobi.Var C68 (value 0.0)>, (2, 3): <gurobi.Var C69 (value 0.04999999999999993)>, (2, 4): <gurobi.Var C70 (value 0.04999999999999993)>, (2, 5): <gurobi.Var C71 (value 0.0)>, (2, 6): <gurobi.Var C72 (value 0.0)>, (2, 7): <gurobi.Var C73 (value 0.0)>, (2, 8): <gurobi.Var C74 (value 0.0)>, (2, 9): <gurobi.Var C75 (value 0.0)>, (2, 10): <gurobi.Var C76 (value 0.0)>, (2, 11): <gurobi.Var C77 (value 0.07500000000000018)>, (2, 12): <gurobi.Var C78 (value 0.8249999999999998)>, (2, 13): <gurobi.Var C79 (value 0.0)>, (2, 14): <gurobi.Var C80 (value 0.0)>, (2, 15): <gurobi.Var C81 (value 0.0)>, (2, 16): <gurobi.Var C82 (value 0.0)>, (2, 17): <gurobi.Var C83 (value 0.0)>, (2, 18): <gurobi.Var C84 (value 0.0)>, (2, 19): <gurobi.Var C85 (value 0.0)>, (2, 20): <gurobi.Var C86 (value 0.0)>, (2, 21): <gurobi.Var C87 (value 0.0)>, (2, 22): <gurobi.Var C88 (value 0.0)>, (2, 23): <gurobi.Var C89 (value 0.0)>, (2, 24): <gurobi.Var C90 (value 0.0)>, (2, 25): <gurobi.Var C91 (value 0.0)>, (2, 26): <gurobi.Var C92 (value 0.0)>, (2, 27): <gurobi.Var C93 (value 0.0)>, (2, 28): <gurobi.Var C94 (value 0.0)>, (2, 29): <gurobi.Var C95 (value 0.0)>, (2, 30): <gurobi.Var C96 (value 0.0)>, (2, 31): <gurobi.Var C97 (value 0.0)>, (2, 32): <gurobi.Var C98 (value 0.0)>, (3, 0): <gurobi.Var C99 (value 0.0)>, (3, 1): <gurobi.Var C100 (value 0.0)>, (3, 2): <gurobi.Var C101 (value 0.0499 ...

# %%
# active_arcs = [a for a in A if x[a].x > 0.99]
# non_active_arcs = [a for a in A if x[a].x <= 0.99]

active_arcs = []
non_active_arcs = []



for a in A:
    if x[a].x > 0.99:
        active_arcs.append(a)
    else:
        non_active_arcs.append(a)
        
print(x)
# Out:
# {(0, 0): <gurobi.Var C0 (value 4.0)>, (0, 1): <gurobi.Var C1 (value 0.0)>, (0, 2): <gurobi.Var C2 (value 0.0)>, (0, 3): <gurobi.Var C3 (value 0.0)>, (0, 4): <gurobi.Var C4 (value 0.0)>, (0, 5): <gurobi.Var C5 (value 0.0)>, (0, 6): <gurobi.Var C6 (value 0.0)>, (0, 7): <gurobi.Var C7 (value 0.0)>, (0, 8): <gurobi.Var C8 (value 0.0)>, (0, 9): <gurobi.Var C9 (value 0.0)>, (0, 10): <gurobi.Var C10 (value 0.0)>, (0, 11): <gurobi.Var C11 (value 0.0)>, (0, 12): <gurobi.Var C12 (value 0.0)>, (0, 13): <gurobi.Var C13 (value 0.0)>, (0, 14): <gurobi.Var C14 (value 0.0)>, (0, 15): <gurobi.Var C15 (value 0.0)>, (0, 16): <gurobi.Var C16 (value 0.0)>, (0, 17): <gurobi.Var C17 (value 0.0)>, (0, 18): <gurobi.Var C18 (value 0.0)>, (0, 19): <gurobi.Var C19 (value 0.0)>, (0, 20): <gurobi.Var C20 (value 0.0)>, (0, 21): <gurobi.Var C21 (value 0.0)>, (0, 22): <gurobi.Var C22 (value 0.0)>, (0, 23): <gurobi.Var C23 (value 0.0)>, (0, 24): <gurobi.Var C24 (value 0.0)>, (0, 25): <gurobi.Var C25 (value 0.0)>, (0, 26): <gurobi.Var C26 (value 0.0)>, (0, 27): <gurobi.Var C27 (value 0.0)>, (0, 28): <gurobi.Var C28 (value 0.0)>, (0, 29): <gurobi.Var C29 (value 0.0)>, (0, 30): <gurobi.Var C30 (value 0.0)>, (0, 31): <gurobi.Var C31 (value 0.0)>, (0, 32): <gurobi.Var C32 (value 0.0)>, (1, 0): <gurobi.Var C33 (value 0.0)>, (1, 1): <gurobi.Var C34 (value 0.0)>, (1, 2): <gurobi.Var C35 (value 0.0)>, (1, 3): <gurobi.Var C36 (value 0.0)>, (1, 4): <gurobi.Var C37 (value 0.0)>, (1, 5): <gurobi.Var C38 (value 0.0)>, (1, 6): <gurobi.Var C39 (value 0.0)>, (1, 7): <gurobi.Var C40 (value 0.0)>, (1, 8): <gurobi.Var C41 (value 0.0)>, (1, 9): <gurobi.Var C42 (value 0.0)>, (1, 10): <gurobi.Var C43 (value 0.0)>, (1, 11): <gurobi.Var C44 (value 0.0)>, (1, 12): <gurobi.Var C45 (value 0.0)>, (1, 13): <gurobi.Var C46 (value 1.0)>, (1, 14): <gurobi.Var C47 (value 0.0)>, (1, 15): <gurobi.Var C48 (value 0.0)>, (1, 16): <gurobi.Var C49 (value 0.0)>, (1, 17): <gurobi.Var C50 (value 0.0)>, (1, 18): <gurobi.Var C51 (value 0.0)>, (1, 19): <gurobi.Var C52 (value 0.0)>, (1, 20): <gurobi.Var C53 (value 0.0)>, (1, 21): <gurobi.Var C54 (value 0.0)>, (1, 22): <gurobi.Var C55 (value 0.0)>, (1, 23): <gurobi.Var C56 (value 0.0)>, (1, 24): <gurobi.Var C57 (value 0.0)>, (1, 25): <gurobi.Var C58 (value 0.0)>, (1, 26): <gurobi.Var C59 (value 0.0)>, (1, 27): <gurobi.Var C60 (value 0.0)>, (1, 28): <gurobi.Var C61 (value 0.0)>, (1, 29): <gurobi.Var C62 (value 0.0)>, (1, 30): <gurobi.Var C63 (value 0.0)>, (1, 31): <gurobi.Var C64 (value 0.0)>, (1, 32): <gurobi.Var C65 (value 0.0)>, (2, 0): <gurobi.Var C66 (value 0.0)>, (2, 1): <gurobi.Var C67 (value 0.0)>, (2, 2): <gurobi.Var C68 (value 0.0)>, (2, 3): <gurobi.Var C69 (value 0.04999999999999993)>, (2, 4): <gurobi.Var C70 (value 0.04999999999999993)>, (2, 5): <gurobi.Var C71 (value 0.0)>, (2, 6): <gurobi.Var C72 (value 0.0)>, (2, 7): <gurobi.Var C73 (value 0.0)>, (2, 8): <gurobi.Var C74 (value 0.0)>, (2, 9): <gurobi.Var C75 (value 0.0)>, (2, 10): <gurobi.Var C76 (value 0.0)>, (2, 11): <gurobi.Var C77 (value 0.07500000000000018)>, (2, 12): <gurobi.Var C78 (value 0.8249999999999998)>, (2, 13): <gurobi.Var C79 (value 0.0)>, (2, 14): <gurobi.Var C80 (value 0.0)>, (2, 15): <gurobi.Var C81 (value 0.0)>, (2, 16): <gurobi.Var C82 (value 0.0)>, (2, 17): <gurobi.Var C83 (value 0.0)>, (2, 18): <gurobi.Var C84 (value 0.0)>, (2, 19): <gurobi.Var C85 (value 0.0)>, (2, 20): <gurobi.Var C86 (value 0.0)>, (2, 21): <gurobi.Var C87 (value 0.0)>, (2, 22): <gurobi.Var C88 (value 0.0)>, (2, 23): <gurobi.Var C89 (value 0.0)>, (2, 24): <gurobi.Var C90 (value 0.0)>, (2, 25): <gurobi.Var C91 (value 0.0)>, (2, 26): <gurobi.Var C92 (value 0.0)>, (2, 27): <gurobi.Var C93 (value 0.0)>, (2, 28): <gurobi.Var C94 (value 0.0)>, (2, 29): <gurobi.Var C95 (value 0.0)>, (2, 30): <gurobi.Var C96 (value 0.0)>, (2, 31): <gurobi.Var C97 (value 0.0)>, (2, 32): <gurobi.Var C98 (value 0.0)>, (3, 0): <gurobi.Var C99 (value 0.0)>, (3, 1): <gurobi.Var C100 (value 0.0)>, (3, 2): <gurobi.Var C101 (value 0.0499 ...

# %%
plt.rcParams["figure.figsize"] = [16,9]

for i, j in active_arcs:
    plt.plot([xc[i], xc[j]], [yc[i], yc[j]], c='black', zorder=0)
plt.plot(xc[0], yc[0], c='r', marker='s')
plt.scatter(xc[1:], yc[1:], c='black')

# %%
plt.rcParams["figure.figsize"] = [16,9]

for i, j in non_active_arcs:
    plt.plot([xc[i], xc[j]], [yc[i], yc[j]], c='black', zorder=0)
plt.plot(xc[0], yc[0], c='r', marker='s')
plt.scatter(xc[1:], yc[1:], c='black')

# %%
mdl.printStats()
# Out:
# Statistics for model CVRP :
#   Linear constraint matrix    : 1122 Constrs, 1121 Vars, 5154 NZs
#   Matrix coefficient range    : [ 1, 8000 ]
#   Objective coefficient range : [ 1, 118.87 ]
#   Variable bound range        : [ 0, 0 ]
#   RHS coefficient range       : [ 1, 8000 ]
